# %%
import pandas as pd
import datetime 
from datetime import date, datetime, time
import matplotlib.pyplot as plt

import yfinance as yf
start = datetime(2020, 1, 1)
end = datetime(2020, 12, 31)

sec = yf.download(tickers=['005930.KS'],start=start,end=end)
sec.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2020-01-02  47372.843750  48059.406703  47201.203012  47630.304857  12993228
# 2020-01-03  47630.312500  48574.336712  47115.390203  48059.414414  15422255
# 2020-01-06  47630.312500  47716.132883  46857.929054  47115.390203  10278951
# 2020-01-07  47887.769531  48402.691784  47716.128780  47801.949156  10009778
# 2020-01-08  48745.972656  49260.894903  47973.589287  48231.050410  23501171
