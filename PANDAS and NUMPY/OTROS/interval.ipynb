# %%
import pandas as pd
import numpy as np
import datetime

from datetime import date, datetime, time, timezone
datetime(2023, 7, 7)
date
time 
timezone
# Out:
# datetime.timezone

# %%
datetime(2021, 7, 7, 15, 50)
# Out:
# datetime.datetime(2021, 7, 7, 15, 50)

# %%
d = date(2021,7,7)
t = time(13, 16, 10)
datetime.combine(d, t)
# Out:
# datetime.datetime(2021, 7, 7, 13, 16, 10)

# %%
datetime.now()
datetime.now(timezone.utc)
# Out:
# /
# datetime.datetime(2026, 6, 16, 14, 49, 5, 196490, tzinfo=datetime.timezone.utc)

# %%
datetime.now().date()
# Out:
# datetime.date(2026, 6, 16)

# %%
pd.Timestamp('now')
# Out:
# Timestamp('2026-06-16 16:58:30.144984')

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
my_birth = datetime(2001, 10, 3)
today = datetime.today()
tommorrow = today + pd.Timedelta(days = 1)
print(tommorrow - my_birth)
# Out:
# 9023 days, 17:10:26.995225

# %%
import pandas as pd

wti = pd.read_csv("data/sample/DCOILWTICO.csv")

# %%
wti.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        1770 non-null   str
#  1   DCOILWTICO  1770 non-null   str
# dtypes: str(2)
# memory usage: 27.8 KB

# %%
wti.head()
# Out:
#          DATE DCOILWTICO
# 0  2016-11-01      46.66
# 1  2016-11-02      45.32
# 2  2016-11-03      44.66
# 3  2016-11-04      44.07
# 4  2016-11-07      44.88

# %%
pd.date_range(start='2021-01-01',end=None, Periods=5, freq='M', tz=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6313, in pandas._libs.tslibs.offsets.to_offset()
# -> 6313 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/offsets.pyx:6180, in pandas._libs.tslibs.offsets._validate_to_offset_alias()
# -> 6180 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: 'M' is no longer supported for offsets. Please use 'ME' instead.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pd.date_range(start='2021-01-01',end=None, Periods=5, freq='M', tz=None)
#
# ...
