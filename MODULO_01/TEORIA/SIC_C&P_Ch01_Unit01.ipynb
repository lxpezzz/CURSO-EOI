# %% [markdown]
# ## Mission

# %% [markdown]
# ### 3.3. Resume Program: Final Codes

# %%
print('Hello! I will introduce myself.')
print('Name: David Doe')
print('Age: 23')
print('Job: Data Scientist')
print('Address: Seoul, South Korea')
print('Place of Birth: Southern California, USA')
# Out:
# Hello! I will introduce myself.
# Name: David Doe
# Age: 23
# Job: Data Scientist
# Address: Seoul, South Korea
# Place of Birth: Southern California, USA

# %% [markdown]
# ## Key concept

# %% [markdown]
# ### 2.3 Annotation

# %%
#define the variable as a radius
radius = 4.0

#print the radius, area, and circumference of the circle
print('Radius', radius)
print('Area', 3.14 * radius * radius)       #Apply the formula to solve for the area of a circle
print('Circumference', 2.0 * 3.14 * radius) #Apply the formula to solve for the circumference of the circle
# Out:
# Radius 4.0
# Area 50.24
# Circumference 25.12

# %%
'''
You can create a multiple-line annotations using double quotatiion marks.
It allows you to make multiple lines of comments.
'''
# Out:
# '\nYou can create a multiple-line annotations using double quotatiion marks.\nIt allows you to make multiple lines of comments.\n'

# %%
"""
It allows you to make multiple lines of comments.
It allows you to make multiple lines of comments.
"""
# Out:
# '\nIt allows you to make multiple lines of comments.\nIt allows you to make multiple lines of comments.\n'

# %% [markdown]
# ## Let's code

# %% [markdown]
# ### 4.2 Printing String and Value

# %%
print('Hello World!')
print("Hello World!")
# Out:
# Hello World!
# Hello World!

# %%
print(10)
print(7.5)
# Out:
# 10
# 7.5

# %%
print(10 + 7.5)
print(10 - 7.5)
# Out:
# 17.5
# 2.5

# %% [markdown]
# ### 4.3 Adding a New Line

# %%
print('Hello\nWorld!')
# Out:
# Hello
# World!

# %%
print('''Hello
World!''')
# Out:
# Hello
# World!

# %%
print('''Hello\
World!''')
# Out:
# HelloWorld!

# %% [markdown]
# ### 4.4. The Comma(,) Additions(+), Multiplication(*) Operators

# %%
print('Hello', 'World!')
print(10, 20)
# Out:
# Hello World!
# 10 20

# %%
print('Hello', 10)
# Out:
# Hello 10

# %%
print('Hello' + 'World!')
print(10 + 20)
# Out:
# HelloWorld!
# 30

# %%
print('Hello' + 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print('Hello' + 10)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('Hello' * 3)
print(10 * 20)
# Out:
# HelloHelloHello
# 200

# %%
print('Hello' * 'World!')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print('Hello' * 'World!')
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ### 4.5 End and Split Parameters

# %%
print('Hello', end='')
print('World!')
# Out:
# HelloWorld!

# %%
print('Hello', end=',')
print('World!')
# Out:
# Hello,World!

# %%
print('Hello', 'World!', sep='')
# Out:
# HelloWorld!

# %%
print('Hello', 'World!', sep=',')
# Out:
# Hello,World!

# %% [markdown]
# ### 4.6. Creating a Resume

# %%
print('Hello! I will introduce myself.')
print('Name: David Doe')
print('Age: 23')
print('Job: Data Scientist')
print('Address: Seoul, South Korea')
print('Place of Birth: Southern California, USA')
# Out:
# Hello! I will introduce myself.
# Name: David Doe
# Age: 23
# Job: Data Scientist
# Address: Seoul, South Korea
# Place of Birth: Southern California, USA

# %%
print('***************************************')
print('---------------------------------------')
# Out:
# ***************************************
# ---------------------------------------

# %% [markdown]
# ### 5.2. Code lay out

# %%
a = 10; a += 10; print(a) # Bad case
# Out:
# 20

# %%
a = 10   # Good case
a += 10
print(a)
# Out:
# 20

# %%
width = 0
height = 0
color = 'red' 
emphasis = 'string'
highlight = 100

# %%
if width == 0 and height == 0 and color == 'red' and emphasis == 'string' or highlight > 100:
    print('Sorry, you rose.')
# Out:
# Sorry, you rose.

# %%
if width == 0 and height == 0 and color == 'red' and \
    emphasis == 'string' or highlight > 100:
    print('Sorry, you rose.')
# Out:
# Sorry, you rose.

# %%
a=[1,2,3]     # Bad

# %%
a = [1, 2, 3] # Good

# %% [markdown]
# ### 6.1. Syntax Error

# %%
print('Hello)
# Out:
#   Cell In[30], line 1
#     print('Hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
num = int(input('Input an integer: '))
# Out:
# Input an integer: two
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 num = int(input('Input an integer: '))
#
# ValueError: invalid literal for int() with base 10: 'two'

# %%
try:
    a, b = input('Enter two integers: ').split()
    result = int(a) / int(b)
    print('{}/{} = {}'.format(a, b, result))
except:
    print('Check if the integers are correctly entered.')
# Out:
# Enter two integers: 10 2
# 10/2 = 5.0

# %%
try:
    a, b = input('Enter two integers: ').split()
    result = int(a) / int(b)
    print('{}/{} = {}'.format(a, b, result))
except:
    print('Check if the integers are correctly entered.')
# Out:
# Enter two integers: 10 two
# Check if the integers are correctly entered.

# %%
try:
    a, b = input('Enter two integers: ').split()
    result = int(a) / int(b)
    print('{}/{} = {}'.format(a, b, result))
except:
    print('Check if the integers are correctly entered.')
# Out:
# Enter two integers: 10 0
# Check if the integers are correctly entered.
