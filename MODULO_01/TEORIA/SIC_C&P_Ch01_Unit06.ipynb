# %% [markdown]
# ## Mission

# %% [markdown]
# ### 2. Mission

# %%
n1, n2, n3 = 2, 3, 9
n = 0
a, b, c = input('Enter a three-digit lottery number : ').split()
a = int(a)
b = int(b)
c = int(c)
if a == n1 or a == n2 or a == n3: # If one of the numbers match the winning number
    n += 1                        #Increase n
if b == n1 or b == n2 or b == n3:
    n+= 1
if c == n1 or c == n2 or c == n3:
    n += 1
if n == 3:                       # If n is 3, three numbers matched
    print('You won the lottery!')
# Out:
# Enter a three-digit lottery number : 1 2 9

# %% [markdown]
# ## Key concept

# %% [markdown]
# ### 1. if Conditional Statements

# %%
num = 100
print('num = ', num)   # 100 is printed
num = num + 100
print('num = ', num)   # 100 is added to num and 200 is printed
num = num + 100
print('num = ', num)   # 100 is added again to num and 300 is printed
# Out:
# num =  100
# num =  200
# num =  300

# %%
age = 18        # if age is 18
if age < 20:    # result of age ‹ 20 is True
    print('youth discount')
# Out:
# youth discount

# %%
age = 24        # if age is 20
if age < 20:    # result of age ‹ 20 is False
    print('youth discount')

# %%
age = 18
if age < 20:
print('youth discount')
# Out:
#   Cell In[12], line 3
#     print('youth discount')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age = 18
if age < 20:
    print('youth discount')
print('Welcome')
# Out:
# youth discount
# Welcome

# %%
age = 24
if age < 20:
    print('youth discount')
print('Welcome')
# Out:
# Welcome

# %%
age = 18
if age < 20:
    print('age', age)
    print('youth welcome')
    print('youth discount')
# Out:
# age 18
# youth welcome
# youth discount

# %%
age = 24
if age < 20:
    print('age', age)
    print('youth welcome')
    print('youth discount')

# %%
age = 18
if age < 20:
    print('age', age)
   print('youth welcome')
  print('youth discount')
# Out:
#   File <tokenize>:4
#     print('youth welcome')
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
age = 18
if age < 20: print('youth discount')  # Bad coding
# Out:
# youth discount

# %%
age = 18
if age < 20:
    print('youth discount')  # Good coding
# Out:
# youth discount

# %% [markdown]
# ### 2. Applying Numeric and String Conditions to Conditional Statements

# %%
number = int(input('Enter an integer: '))    # Change input value to integer type
if (number % 3) == 0:
    print (number, 'is a multiple of 3.')
# Out:
# Enter an integer: 6
# 6 is a multiple of 3.

# %%
number = int (input ('Enter an integer: '))
if (number % 3) == 0 and (number % 5) == 0:
    print(number, 'is a multiple of 3 and 5.')
# Out:
# Enter an integer: 15
# 15 is a multiple of 3 and 5.

# %%
my_id = 'david'
s = input('Enter your id: ')
if s == my_id:
    print('ID matches.')
# Out:
# Enter your id: david
# ID matches.

# %% [markdown]
# ### 3. Various scenarios of conditions

# %%
n = int(input("Enter an integer : "))
print("n =", n)
if n % 2 == 0 :
    print(n, "is an even number.")
# Out:
# Enter an integer : 50
# n = 50
# 50 is an even number.

# %%
str1 = 'aaa'
str2 = 'bbb'
if str1 == str2:
    print('Two strings match.')
if str1 != str2:
    print('Two strings are different.')
# Out:
# Two strings are different.

# %% [markdown]
# ### 4. pass Keyword

# %%
num = 2
if num % 2 == 0:
    print('Even number')
if num % 3 == 0:
    pass
# Out:
# Even number

# %%
def func() :
    pass

func()

# %%
def func() :


func()
# Out:
#   Cell In[30], line 4
#     func()
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# ## Let’s code

# %% [markdown]
# ### 1. If Statement

# %%
x = 100
if x > 1:
    print("x is greater than 1.")
# Out:
# x is greater than 1.

# %%
score = int(input("Enter the score: "))
if score >= 90 :             # if the condition is true, block indent is all executed
    print("Congratulations.")
    print("You are accepted.")
    print("You are qualified for a scholarship.")
# Out:
# Enter the score: 95
# Congratulations.
# You are accepted.
# You are qualified for a scholarship.

# %%
score = int(input("Enter the score: "))
if score >= 90 :             # Caution : if indentation is different an error occurs
 print("Congratulations.")
  print("You are accepted.")
   print("You are qualified for a scholarship.")
# Out:
#   Cell In[35], line 4
#     print("You are accepted.")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 2. Use of String and Spilt Method

# %%
words = 'Python is beautiful'
word_list = words.split()
print(word_list)
# Out:
# ['Python', 'is', 'beautiful']

# %%
str1 = input('Enter three integers divided by space: ')
print('Input: ', str1)
print('Input separated by split() method: ', str1.split())
# Out:
# Enter three integers divided by space: 10 20 30
# Input:  10 20 30
# Input separated by split() method:  ['10', '20', '30']

# %%
str1 = input ('Enter three integers separated by ,: ')
print('Input: ', str1)
print('Input separated by split() method: ', str1.split(','))
# Out:
# Enter three integers separated by ,: 10,20,30
# Input:  10,20,30
# Input separated by split() method:  ['10', '20', '30']

# %%
num1, num2, num3 = input ('Enter three integers separated by ,: ').split(',')
num1, num2, num3 = int (num1), int (num2), int (num3)
print (num1, num2, num3)
# Out:
# Enter three integers separated by ,: 5,6,7
# 5 6 7
