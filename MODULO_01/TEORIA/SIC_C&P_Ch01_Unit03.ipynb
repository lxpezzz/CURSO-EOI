# %% [markdown]
# ## Mission

# %% [markdown]
# ### 3.2. How printing the circumference and area of the circle works

# %%
PI = 3.14
radius = float(input('Enter the radius :'))
area = PI * radius * radius
circum = 2.0 * PI * radius

print('Radious of the circle', radius)
print('Area of the circle', area)
print('Circumference of the circle', circum)
# Out:
# Enter the radius :4.0
# Radious of the circle 4.0
# Area of the circle 50.24
# Circumference of the circle 25.12

# %% [markdown]
# ## Key concept

# %% [markdown]
# ### 1.3. Example code using operator

# %%
100 + 20 # Find addition of numerical value of 100 and 20
# Out:
# 120

# %%
100 * 20 # Find multiplication of numerical value of 100 and 20
# Out:
# 2000

# %%
100 - 20 # Find subtraction of numerical value of 100 and 20
# Out:
# 80

# %%
100 / 20 # Divide numerical value of 100 with 20
# Out:
# 5.0

# %%
100 // 20 # Divide numerical value of 100 with 20 and find quotient
# Out:
# 5

# %%
100 % 20 # Divide numerical value of 100 with 20 and find remainder
# Out:
# 0

# %% [markdown]
# ### 2.1. Classification of data types

# %%
10 / 2
# Out:
# 5.0

# %%
'10' / 2 # String 10 divided by number 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 '10' / 2 # String 10 divided by number 2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
100 * 2 # Find multiplication of numerical value 100 and 2
# Out:
# 200

# %%
'Hello' * 2 # Find multiplication of string 'Hello' and 2
# Out:
# 'HelloHello'

# %%
'100' * 2 # Find multiplication of string '100' and 2
# Out:
# '100100'

# %% [markdown]
# ### 2.3. How to distinguish data types

# %%
type(100) # Let you know data type of 100
# Out:
# int

# %%
type (100.0) # Let you know data type of 100
# Out:
# float

# %%
type('100') # Let you know data type of 100
# Out:
# str

# %%
type(10 + 3j) # Complex number data type in the form of real + imaginary numbers like 10 + 3j
# Out:
# complex

# %% [markdown]
# ### 2.4. Precedence of operators

# %%
10 + 20 * 30 # Multiplication is calculated first.
# Out:
# 610

# %%
(10 + 20) * 30 # Operator in parentheses is calculated first.
# Out:
# 900

# %% [markdown]
# ### 2.6. Data type conversion

# %%
int('10') / 2 # Convert string '10' into integer and divide by 2.
# Out:
# 5.0

# %%
'I like number ' + str (10) # Convert number 10 into string and use + operator
# Out:
# 'I like number 10'

# %%
a = None
type(a)
# Out:
# NoneType

# %% [markdown]
# ### 3.2. String operator +, *

# %%
'I' + ' Love' + ' Python!' # String can be added to strings.
# Out:
# 'I Love Python!'

# %%
'Python ' * 10 # Generates string of 'Python' repeated 10 times
# Out:
# 'Python Python Python Python Python Python Python Python Python Python '

# %%
'*' * 50 #Generates string of '*' repeated 50 times
# Out:
# '**************************************************'

# %%
str (100) * 10 #String '100' repeats 10 times
# Out:
# '100100100100100100100100100100'

# %%
'*' * 3.1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 '*' * 3.1
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
"A" + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 "A" + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
"10" + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 "10" + 10
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Let’s code

# %% [markdown]
# ### 1.1. Arithmetic operation

# %%
1 + 5
# Out:
# 6

# %%
1 - 8
# Out:
# -7

# %%
4 * 5
# Out:
# 20

# %%
5 // 3
# Out:
# 1

# %% [markdown]
# ### 1.2. Power, remainder

# %%
2 ** 10
# Out:
# 1024

# %%
9 % 5
# Out:
# 4

# %% [markdown]
# ### 1.3. Mixed operation

# %%
1 + 2 * 5
# Out:
# 11

# %%
(1 + 2) * 5
# Out:
# 15

# %% [markdown]
# ### 1.4. Complex number operation

# %%
(3 + 4j ) + (5 + 2j ) # Addition of complex numbers
# Out:
# (8+6j)

# %%
(3 + 4j) - (5 + 2j ) # Subtraction of complex numbers
# Out:
# (-2+2j)

# %%
(3 + 4j) * ( 5 + 2j ) # Multiplication of complex numbers
# Out:
# (7+26j)

# %%
(3 + 4j ) / (5 + 2j ) # Division of complex numbers
# Out:
# (0.793103448275862+0.48275862068965514j)

# %% [markdown]
# ### 2.1. Identifying and converting data types

# %%
int("10")   # Convert string “10” to integer 10
# Out:
# 10

# %%
type(10)
# Out:
# int

# %%
type("10")
# Out:
# str

# %%
type(10.5)
# Out:
# float

# %%
type (10) # Cell output is int
# Out:
# int

# %%
print(type(10)) # Cell output is ‹class 'int'
# Out:
# <class 'int'>

# %% [markdown]
# ### 2.2. How to convert a data type

# %%
int("50")
# Out:
# 50

# %%
int("50") + 20
# Out:
# 70

# %%
"10" + str(10)
# Out:
# '1010'

# %%
float("10.5")
# Out:
# 10.5

# %% [markdown]
# ### 3.1. Addition and Multiplication Operators of String

# %%
"Hello" + "World"
# Out:
# 'HelloWorld'

# %%
"text" + "repeat" * 10
# Out:
# 'textrepeatrepeatrepeatrepeatrepeatrepeatrepeatrepeatrepeatrepeat'

# %% [markdown]
# ### 3.2. Single and Double Quotation Marks

# %%
print("Hello World!")
print('Hello World!')
# Out:
# Hello World!
# Hello World!

# %% [markdown]
# ### 3.3. Using comma

# %%
print('I am', 23, 'years old!')
print('I', 'really ' * 3, 'love', 'Python!')
# Out:
# I am 23 years old!
# I really really really  love Python!

# %% [markdown]
# ### 3.4. Escape sequence

# %%
print("\"double quotation marks\"")
# Out:
# "double quotation marks"

# %%
print("\'single quotation marks\'")
# Out:
# 'single quotation marks'

# %%
print("line \nbreak")
# Out:
# line
# break

# %%
print("Enter a \t tab in the middle of the sentence.")
# Out:
# Enter a 	 tab in the middle of the sentence.

# %%
print("\tEnter a tab at first!")
# Out:
# 	Enter a tab at first!

# %% [markdown]
# ### 3.5. String indexing

# %%
"hello"[0]
# Out:
# 'h'

# %%
"hello"[2]
# Out:
# 'l'

# %% [markdown]
# ### 3.6. Negative string indexing

# %%
"hello"[-1]
# Out:
# 'o'

# %%
"hello"[-5]
# Out:
# 'h'

# %%
"hello"[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 "hello"[5]
#
# IndexError: string index out of range
