# %%
print('Hola Héctor')
print('como estas')
# Out:
# Hola Héctor
# como estas

# %%
# Defino la variable como el radio
radius = 4.0

# Imprimo el radio, área, y la formula de la circunferencia del círculo.
print('Radius', radius)
print('Area', 3.14 * radius * radius)       # Aplico la fórmula del área 
                                            # del círculo.
print('Circunference', 2.0 * 3.14 * radius) #Aplico la fórmula de la 
                                            #circunferencia del circulo.
# Out:
# Radius 4.0
# Area 50.24
# Circungerence 25.12

# %%
'''
yo puedo crear multiples líneas de comentarios con ''''''
'''
print('con comillas simples')
# Out:
# con comillas simples
