# %%
# Q1 PAG 193
# a) True
# b

# %%
# Q2 PAG 194
ventas = (100, 121, 120, 130, 140, 120, 122, 123, 190, 125)
contador = 0
for i in range(1, len(ventas)):
    if ventas[i] < ventas[i - 1]:
        count += 1

print(f"En los últimos 10 dias, {contador} dias se han reducido la ventas comparadas con el dia anterior")
