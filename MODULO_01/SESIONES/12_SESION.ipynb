# %%
# Q1 pag 262
def greeting():
    def say_hi():
        print('Hello!')
    say_hi()
greeting()
# Out:
# Hello!

# %%
# Q2 PAG 263
def calc():
    a = 3
    b = 5 
    def mul_add(x):
        return a * x + b
    return mul_add
num = calc()
print(num(3))
# Out:
# 14

# %%
# q3 paf 264
def calc():
    a = 3
    b = 5
    mul_add = lambda x: a * x + b 
    return mul_add


num = calc()
print(num(3))
# Out:
# 14

# %%
# Q1 PAG 348
class Dog:
    def bark():
